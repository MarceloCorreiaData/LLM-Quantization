# %% [markdown]
# ## LoftQ novo método com biblioteca PEFT própria - quantize_save_load
#
# Erro em 4bits - quantização do Mistral Instruct
#
# Obs.: Diferentes modelos em diferentes ambientes de dev foram testatos (Falcon, Mistral, Llama2), apresentando erro de quantização em 8 e 4-bit. \
# Os erros são atribuídos a falhas no PEFT alternativo criado pelo desenvolvedor e instalado na máquina

# %%
! python quantize_save_load.py  --model_name mistralai/Mistral-7B-Instruct-v0.1 --bits 4 --iter 5  --rank 16 --save_dir /content/drive/MyDrive/loftq_finetuning/mistral
# Out:
# tokenizer_config.json: 100% 1.47k/1.47k [00:00<00:00, 7.91MB/s]
# tokenizer.model: 100% 493k/493k [00:00<00:00, 2.90MB/s]
# tokenizer.json: 100% 1.80M/1.80M [00:00<00:00, 7.07MB/s]
# special_tokens_map.json: 100% 72.0/72.0 [00:00<00:00, 436kB/s]
# config.json: 100% 571/571 [00:00<00:00, 3.47MB/s]
# pytorch_model.bin.index.json: 100% 23.9k/23.9k [00:00<00:00, 77.5MB/s]
# ...
# pytorch_model-00001-of-00002.bin:   0% 0.00/9.94G [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0% 10.5M/9.94G [00:00<04:35, 36.1MB/s]
# pytorch_model-00001-of-00002.bin:   0% 21.0M/9.94G [00:00<04:57, 33.4MB/s]
# pytorch_model-00001-of-00002.bin:   0% 31.5M/9.94G [00:00<04:09, 39.8MB/s]
# pytorch_model-00001-of-00002.bin:   0% 41.9M/9.94G [00:01<03:47, 43.5MB/s]
# pytorch_model-00001-of-00002.bin:   1% 52.4M/9.94G [00:01<03:51, 42.8MB/s]
# pytorch_model-00001-of-00002.bin:   1% 62.9M/9.94G [00:01<04:19, 38.0MB/s]
# pytorch_model-00001-of-00002.bin:   1% 73.4M/9.94G [00:01<04:16, 38.5MB/s]
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# ## LoftQ novo método - quantize_save_load
# Assertion Eror em 8 bits

# %% [markdown]
# ## Llama2

# %% [markdown]
# Deve logar no HuggingFace da Meta/Llama:
# 1. Abrir Terminal \
# 2. huggingface-cli login \
# 3. Colar o token do huggingface \
# 4. y

# %%
HF_TOKEN = "xxxxxxxxxx"

# %%
! python quantize_save_load.py --model_name_or_path meta-llama/Llama-2-7b-hf --token HF_TOKEN --bits 8 --iter 1 --rank 16
# Out:
# /opt/conda/lib/python3.10/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# /opt/conda/lib/python3.10/site-packages/bitsandbytes/libbitsandbytes_cpu.so: undefined symbol: cadam32bit_grad_fp32
# Loading checkpoint shards: 100%|██████████████████| 2/2 [02:59<00:00, 89.74s/it]
# Traceback (most recent call last):
#   File "/home/jupyter/LoftQ/quantize_save_load.py", line 236, in <module>
#     base_dir, lora_dir = quantize_and_save()
#   File "/home/jupyter/LoftQ/quantize_save_load.py", line 163, in quantize_and_save
#     lora_model = get_peft_model(model, lora_config)
#   File "/opt/conda/lib/python3.10/site-packages/peft/mapping.py", line 116, in get_peft_model
# ...

# %% [markdown]
# # Mistral

# %%
! python quantize_save_load.py  --model_name mistralai/Mistral-7B-v0.1 --bits 4 --iter 5  --rank 16
# Out:
# /opt/conda/lib/python3.10/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# /opt/conda/lib/python3.10/site-packages/bitsandbytes/libbitsandbytes_cpu.so: undefined symbol: cadam32bit_grad_fp32
# tokenizer_config.json: 100%|███████████████████| 966/966 [00:00<00:00, 3.03MB/s]
# tokenizer.model: 100%|███████████████████████| 493k/493k [00:00<00:00, 11.3MB/s]
# tokenizer.json: 100%|██████████████████████| 1.80M/1.80M [00:00<00:00, 17.4MB/s]
# special_tokens_map.json: 100%|████████████████| 72.0/72.0 [00:00<00:00, 382kB/s]
# config.json: 100%|█████████████████████████████| 571/571 [00:00<00:00, 3.14MB/s]
# pytorch_model.bin.index.json: 100%|████████| 23.9k/23.9k [00:00<00:00, 78.7MB/s]
# ...

# %% [markdown]
# <hr>
